# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("forestfires.csv")
dataset.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
dataset = pd.read_csv("forestfires.csv")
dataset.head()
dataset.hist(bins=30, figsize=(12,10))
plt.show()

# %%
plt.scatter(dataset["DMC"],dataset["area"])
plt.title("DMC vs Area")
plt.xlabel("DMC")
plt.xlabel("Area")
plt.show()

# %%
sns.displot(data=dataset, x="wind", hue="day", kind="kde")
sns.boxplot(data=dataset, x="wind", y="month")
# Out:
# <AxesSubplot:xlabel='wind', ylabel='month'>

# %%
dataset['burned'] = dataset['area'].apply(lambda x: 0.0 if x == 0.0 else 1.0)
dataset.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area  burned
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0     0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0     0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0     0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0     0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0     0.0

# %%
sns.histplot(data=dataset, x="month", hue="day")
# Out:
# <AxesSubplot:xlabel='month', ylabel='Count'>

# %%
sns.displot(data=dataset, x="wind", kind="kde")

# %%
attribute = ["FFMC", "DMC", "DC", "ISI", "temp", "RH"]
corr = dataset[attribute].corr()
corr
# Out:
#           FFMC       DMC        DC       ISI      temp        RH
# FFMC  1.000000  0.382619  0.330512  0.531805  0.431532 -0.300995
# DMC   0.382619  1.000000  0.682192  0.305128  0.469594  0.073795
# DC    0.330512  0.682192  1.000000  0.229154  0.496208 -0.039192
# ISI   0.531805  0.305128  0.229154  1.000000  0.394287 -0.132517
# temp  0.431532  0.469594  0.496208  0.394287  1.000000 -0.527390
# RH   -0.300995  0.073795 -0.039192 -0.132517 -0.527390  1.000000

# %%
# %matplotlib inline
from pandas.plotting import scatter_matrix

attribute = ['FFMC','DMC','DC','ISI']
scatter_matrix(dataset[attribute],figsize=(20,15))
# Out:
# array([[<AxesSubplot:xlabel='FFMC', ylabel='FFMC'>,
#         <AxesSubplot:xlabel='DMC', ylabel='FFMC'>,
#         <AxesSubplot:xlabel='DC', ylabel='FFMC'>,
#         <AxesSubplot:xlabel='ISI', ylabel='FFMC'>],
#        [<AxesSubplot:xlabel='FFMC', ylabel='DMC'>,
#         <AxesSubplot:xlabel='DMC', ylabel='DMC'>,
#         <AxesSubplot:xlabel='DC', ylabel='DMC'>,
#         <AxesSubplot:xlabel='ISI', ylabel='DMC'>],
#        [<AxesSubplot:xlabel='FFMC', ylabel='DC'>,
#         <AxesSubplot:xlabel='DMC', ylabel='DC'>,
#         <AxesSubplot:xlabel='DC', ylabel='DC'>,
#         <AxesSubplot:xlabel='ISI', ylabel='DC'>],
#        [<AxesSubplot:xlabel='FFMC', ylabel='ISI'>,
#         <AxesSubplot:xlabel='DMC', ylabel='ISI'>,
#         <AxesSubplot:xlabel='DC', ylabel='ISI'>,
#         <AxesSubplot:xlabel='ISI', ylabel='ISI'>]], dtype=object)

# %%
# %matplotlib inline
from pandas.plotting import scatter_matrix

attribute = ['FFMC','DMC','DC','ISI']
scatter_matrix(dataset[attribute],figsize=(20,15))
# Out:
# array([[<AxesSubplot:xlabel='FFMC', ylabel='FFMC'>,
#         <AxesSubplot:xlabel='DMC', ylabel='FFMC'>,
#         <AxesSubplot:xlabel='DC', ylabel='FFMC'>,
#         <AxesSubplot:xlabel='ISI', ylabel='FFMC'>],
#        [<AxesSubplot:xlabel='FFMC', ylabel='DMC'>,
#         <AxesSubplot:xlabel='DMC', ylabel='DMC'>,
#         <AxesSubplot:xlabel='DC', ylabel='DMC'>,
#         <AxesSubplot:xlabel='ISI', ylabel='DMC'>],
#        [<AxesSubplot:xlabel='FFMC', ylabel='DC'>,
#         <AxesSubplot:xlabel='DMC', ylabel='DC'>,
#         <AxesSubplot:xlabel='DC', ylabel='DC'>,
#         <AxesSubplot:xlabel='ISI', ylabel='DC'>],
#        [<AxesSubplot:xlabel='FFMC', ylabel='ISI'>,
#         <AxesSubplot:xlabel='DMC', ylabel='ISI'>,
#         <AxesSubplot:xlabel='DC', ylabel='ISI'>,
#         <AxesSubplot:xlabel='ISI', ylabel='ISI'>]], dtype=object)

# %%
attribute = ['FFMC','DMC','DC','ISI','temp','RH']
corr = dataset[attribute].corr()
corr
# Out:
#           FFMC       DMC        DC       ISI      temp        RH
# FFMC  1.000000  0.382619  0.330512  0.531805  0.431532 -0.300995
# DMC   0.382619  1.000000  0.682192  0.305128  0.469594  0.073795
# DC    0.330512  0.682192  1.000000  0.229154  0.496208 -0.039192
# ISI   0.531805  0.305128  0.229154  1.000000  0.394287 -0.132517
# temp  0.431532  0.469594  0.496208  0.394287  1.000000 -0.527390
# RH   -0.300995  0.073795 -0.039192 -0.132517 -0.527390  1.000000

# %%
dataset.plot(kind="scatter",x="DMC",y="DC",alpha=0.4,figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='DMC', ylabel='DC'>

# %%
corr_matrix = dataset.corr()
corr_matrix["area"].sort_values(ascending=False)
# Out:
# area      1.000000
# burned    0.193224
# temp      0.097844
# DMC       0.072994
# X         0.063385
# DC        0.049383
# Y         0.044873
# FFMC      0.040122
# wind      0.012317
# ISI       0.008258
# rain     -0.007366
# RH       -0.075519
# Name: area, dtype: float64
